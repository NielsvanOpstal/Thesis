# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import shapely
import libpysal
from sklearn.model_selection import train_test_split, GridSearchCV
import os
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import Normalizer
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_auc_score, average_precision_score, precision_score, recall_score

# %%
# df = pd.read_csv("EHfilled_data15.csv", index_col = 0)
def load_data(year):
    os.getcwd()
    df = pd.DataFrame()
    path = "../Data/filled/" + str(year) + "/"
    for filename in os.listdir(path):
        df1 = pd.read_csv(path + filename)
        if df1.geometry.isna().any():
            print(filename)
        df = pd.concat([df, df1])
    df = gpd.GeoDataFrame(df)
    df.geometry = df.geometry.apply(shapely.wkt.loads)
    
    df = df.reset_index()
    df = df.drop(["Unnamed: 0", "index"], axis = 1)
    return df

# %%
df15 = load_data(2015)
df16 = load_data(2016)
df17 = load_data(2017)
df18 = load_data(2018)
df19 = load_data(2019)

# %%
df15.shape
# Out:
# (30974, 43)

# %%
(df15.y==1).sum()
# Out:
# 2214

# %%
class CA:
    
    def __init__(self, df, normalize = True):
        self.X = df[df.columns[:-4]]
        self.y = df.y
        self.w = libpysal.weights.DistanceBand.from_dataframe(df,threshold=150, binary = True, silence_warnings = True)
#         self.X_train, self. X_test, self.y_train, self.y_test = train_test_split(self.X, self.y, test_size=0.3, random_state=2)
        self.X_train, self. X_test, self.y_train, self.y_test = train_test_split(self.X, self.y, test_size=0.3, random_state=2)
        
        if normalize:
            self.transformer = Normalizer().fit(self.X_train)
            self.X_norm = self.transformer.transform(self.X) # normalize full data   
            
    def transition(self, model):
        self.trans_model = model # set the transition model
        self.trans_model.fit(self.transformer.transform(self.X_train), self.y_train) # fit the model on normalized training data        
        self.full_p = pd.DataFrame(self.trans_model.predict_proba(self.X_norm)).set_index(self.X.index) # predict probablities for full data
        
    def neighbor_function(self, train):
        if train:
            # get the neighbors of training set
            neighbors = [self.w.neighbors[x] for x in self.X_train.index]          
            # Keep the transition_probabilities of the training set
            ps = self.full_p.loc[self.X_train.index] 
            
        else:
            # get the neighbors of the test set
            neighbors = [self.w.neighbors[x] for x in self.X_test.index]
            # keep the transition probabilites of the test set
            ps = self.full_p.loc[self.X_test.index] 
            
        # calculate total probability of neighbors and put in dataframe    
        p = pd.DataFrame([self.full_p.loc[x].sum() for x in neighbors])
        p.columns = ["a", "b"]

        # reset and drop indices to ensure proper concatenation
        ps.reset_index(drop = True, inplace = True)
        p.reset_index(drop = True, inplace = True)

        self.ps = pd.concat([p, ps], axis = 1)
            
    def final_bagger(self, model):
        # initializes and trains the bagger that decides the final 0/1 prediction
        self.bag_model = model
        self.bag_model.fit(self.ps, self.y_train)
        
    def train(self, transition_model, bagger_model):
        # trains the CA
        self.transition(transition_model)
        self.neighbor_function(train = True)
        self.final_bagger(bagger_model)
        
    def test(self):
        # tests the CA
        ca.neighbor_function(train = False)
        self.y_pred = self.bag_model.predict(self.ps)
        self.scores = {"AUC": roc_auc_score(self.y_test, self.y_pred), "recall" : recall_score(self.y_test, self.y_pred),
                      "precision" : precision_score(self.y_test, self.y_pred)}
        
    def optimize(self, params, scoring = "roc_auc"):
        # for now only transition function
        self.clf = GridSearchCV(self.trans_model, params, cv = 5, scoring = scoring,
                               verbose = 3)
        self.clf.fit(self.transformer.transform(self.X_train), self.y_train)

# %%
ca = CA(df15)

# %%
clf = RandomForestClassifier()
# clf = MLPClassifier(random_state=1, max_iter=300, hidden_layer_sizes = (200,100,50))
clf_bagger = RandomForestClassifier(max_depth = 4, random_state = 0)
ca.train(clf, clf_bagger)

# %%
params = {"max_depth": [2,4,6,8], "oob_score" : [True, False]}
ca.optimize(params)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END .......max_depth=2, oob_score=True;, score=0.665 total time=   1.4s
# [CV 2/5] END .......max_depth=2, oob_score=True;, score=0.690 total time=   1.4s
# [CV 3/5] END .......max_depth=2, oob_score=True;, score=0.656 total time=   1.4s
# [CV 4/5] END .......max_depth=2, oob_score=True;, score=0.682 total time=   1.4s
# [CV 5/5] END .......max_depth=2, oob_score=True;, score=0.659 total time=   1.4s
# [CV 1/5] END ......max_depth=2, oob_score=False;, score=0.665 total time=   1.2s
# [CV 2/5] END ......max_depth=2, oob_score=False;, score=0.687 total time=   1.2s
# [CV 3/5] END ......max_depth=2, oob_score=False;, score=0.655 total time=   1.2s
# [CV 4/5] END ......max_depth=2, oob_score=False;, score=0.676 total time=   1.2s
# [CV 5/5] END ......max_depth=2, oob_score=False;, score=0.657 total time=   1.2s
# [CV 1/5] END .......max_depth=4, oob_score=True;, score=0.675 total time=   2.3s
# [CV 2/5] END .......max_depth=4, oob_score=True;, score=0.709 total time=   2.4s
# [CV 3/5] END .......max_depth=4, oob_score=True;, score=0.671 total time=   2.4s
# [CV 4/5] END .......max_depth=4, oob_score=True;, score=0.694 total time=   2.3s
# [CV 5/5] END .......max_depth=4, oob_score=True;, score=0.674 total time=   2.4s
# [CV 1/5] END ......max_depth=4, oob_score=False;, score=0.675 total time=   2.2s
# [CV 2/5] END ......max_depth=4, oob_score=False;, score=0.707 total time=   2.2s
# [CV 3/5] END ......max_depth=4, oob_score=False;, score=0.676 total time=   2.2s
# [CV 4/5] END ......max_depth=4, oob_score=False;, score=0.695 total time=   2.2s
# [CV 5/5] END ......max_depth=4, oob_score=False;, score=0.673 total time=   2.2s
# [CV 1/5] END .......max_depth=6, oob_score=True;, score=0.687 total time=   3.3s
# [CV 2/5] END .......max_depth=6, oob_score=True;, score=0.721 total time=   3.3s
# [CV 3/5] END .......max_depth=6, oob_score=True;, score=0.683 total time=   3.3s
# [CV 4/5] END .......max_depth=6, oob_score=True;, score=0.704 total time=   3.3s
# [CV 5/5] END .......max_depth=6, oob_score=True;, score=0.682 total time=   3.3s
# [CV 1/5] END ......max_depth=6, oob_score=False;, score=0.685 total time=   3.1s
# [CV 2/5] END ......max_depth=6, oob_score=False;, score=0.721 total time=   3.1s
# [CV 3/5] END ......max_depth=6, oob_score=False;, score=0.683 total time=   3.1s
# [CV 4/5] END ......max_depth=6, oob_score=False;, score=0.710 total time=   3.1s
# [CV 5/5] END ......max_depth=6, oob_score=False;, score=0.681 total time=   3.1s
# [CV 1/5] END .......max_depth=8, oob_score=True;, score=0.697 total time=   4.1s
# [CV 2/5] END .......max_depth=8, oob_score=True;, score=0.723 total time=   4.4s
# [CV 3/5] END .......max_depth=8, oob_score=True;, score=0.695 total time=   4.6s
# [CV 4/5] END .......max_depth=8, oob_score=True;, score=0.718 total time=   4.6s
# [CV 5/5] END .......max_depth=8, oob_score=True;, score=0.693 total time=   4.8s
# [CV 1/5] END ......max_depth=8, oob_score=False;, score=0.699 total time=   4.2s
# [CV 2/5] END ......max_depth=8, oob_score=False;, score=0.730 total time=   4.0s
# [CV 3/5] END ......max_depth=8, oob_score=False;, score=0.696 total time=   4.0s
# [CV 4/5] END ......max_depth=8, oob_score=False;, score=0.716 total time=   4.0s
# [CV 5/5] END ......max_depth=8, oob_score=False;, score=0.697 total time=   4.0s

# %%
ca.train(ca.clf.best_estimator_, clf_bagger)

# %%
ca.test()

# %%
ca.scores
# Out:
# {'AUC': 0.5430734635765458,
#  'recall': 0.10452418096723869,
#  'precision': 0.29646017699115046}

# %%
# Out:
# array([False, False, False, ..., False, False, False])

# %%
ca.final_bagger(RandomForestClassifier(max_depth = 4, random_state = 0))

# %%
ca.neighbor_function(False)

# %%
precision_score(ca.y_test, ca.bag_model.predict(ca.ps))
# Out:
# 0.5517241379310345

# %%
average_precision_score(ca.bag_model.predict(ca.ps), ca.y_test)
# Out:
# 0.21812896105108287

# %%
(ca.bag_model.predict(ca.ps) == 1).sum()
# Out:
# 0

# %%
ca.ps
(ca.y_train == 1).sum()
# Out:
# 2807

# %%
bag_forest = RandomForestClassifier(max_depth = 4, random_state = 0)

# %%
ps.loc[ca.X_train.index].add(np.array(p))
# Out:
#            0     1
# 35095   4.95  0.05
# 38770   4.96  6.04
# 26006   6.49  0.51
# 3005    6.94  0.06
# 35776   3.00  0.00
# ...      ...   ...
# 31019   8.12  0.88
# 30280   8.87  0.13
# 6637   13.16  1.84
# 35343   7.00  0.00
# 23720   8.69  0.31
#
# [27403 rows x 2 columns]

# %%
a
# Out:
# [0    3.91
#  1    0.09
#  dtype: float64,
#  0    4.82
#  1    5.18
#  dtype: float64,
#  0    5.54
#  1    0.46
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    7.0
#  1    0.0
#  dtype: float64,
#  0    6.9
#  1    1.1
#  dtype: float64,
#  0    6.84
#  1    0.16
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    11.48
#  1     0.52
#  dtype: float64,
#  0    3.76
#  1    0.24
#  dtype: float64,
#  0    14.18
#  1     1.82
#  dtype: float64,
#  0    6.02
#  1    1.98
#  dtype: float64,
#  0    5.25
#  1    2.75
#  dtype: float64,
#  0    13.24
#  1     2.76
#  dtype: float64,
#  0    4.31
#  1    0.69
#  dtype: float64,
#  0    7.15
#  1    0.85
#  dtype: float64,
#  0    11.94
#  1     2.06
#  dtype: float64,
#  0    4.46
#  1    2.54
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    5.9
#  1    0.1
#  dtype: float64,
#  0    6.14
#  1    0.86
#  dtype: float64,
#  0    14.0
#  1     0.0
#  dtype: float64,
#  0    3.82
#  1    0.18
#  dtype: float64,
#  0    4.15
#  1    0.85
#  dtype: float64,
#  0    7.82
#  1    0.18
#  dtype: float64,
#  0    6.74
#  1    3.26
#  dtype: float64,
#  0    13.88
#  1     0.12
#  dtype: float64,
#  0    3.98
#  1    0.02
#  dtype: float64,
#  0    7.91
#  1    0.09
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    6.35
#  1    1.65
#  dtype: float64,
#  0    6.62
#  1    0.38
#  dtype: float64,
#  0    11.86
#  1     2.14
#  dtype: float64,
#  0    10.0
#  1     0.0
#  dtype: float64,
#  0    7.78
#  1    0.22
#  dtype: float64,
#  0    5.45
#  1    2.55
#  dtype: float64,
#  0    8.9
#  1    7.1
#  dtype: float64,
#  0    2.89
#  1    0.11
#  dtype: float64,
#  0    5.94
#  1    2.06
#  dtype: float64,
#  0    16.0
#  1     0.0
#  dtype: float64,
#  0    13.98
#  1     0.02
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    15.865
#  1     0.135
#  dtype: float64,
#  0    7.98
#  1    0.02
#  dtype: float64,
#  0    4.9
#  1    0.1
#  dtype: float64,
#  0    6.98
#  1    0.02
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    7.89
#  1    0.11
#  dtype: float64,
#  0    7.48
#  1    0.52
#  dtype: float64,
#  0    7.43
#  1    0.57
#  dtype: float64,
#  0    13.82
#  1     0.18
#  dtype: float64,
#  0    6.3
#  1    1.7
#  dtype: float64,
#  0    13.64
#  1     0.36
#  dtype: float64,
#  0    4.446667
#  1    2.553333
#  dtype: float64,
#  0    8.5
#  1    5.5
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    7.89
#  1    0.11
#  dtype: float64,
#  0    7.88
#  1    0.12
#  dtype: float64,
#  0    15.48
#  1     0.52
#  dtype: float64,
#  0    5.82
#  1    0.18
#  dtype: float64,
#  0    7.58
#  1    2.42
#  dtype: float64,
#  0    4.86
#  1    2.14
#  dtype: float64,
#  0    12.88
#  1     3.12
#  dtype: float64,
#  0    4.36
#  1    0.64
#  dtype: float64,
#  0    5.55
#  1    2.45
#  dtype: float64,
#  0    6.58
#  1    1.42
#  dtype: float64,
#  0    9.42
#  1    0.58
#  dtype: float64,
#  0    7.63
#  1    0.37
#  dtype: float64,
#  0    7.96
#  1    0.04
#  dtype: float64,
#  0    5.17
#  1    1.83
#  dtype: float64,
#  0    4.89
#  1    0.11
#  dtype: float64,
#  0    15.72
#  1     0.28
#  dtype: float64,
#  0    7.68
#  1    0.32
#  dtype: float64,
#  0    5.143333
#  1    1.856667
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    3.49
#  1    4.51
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    6.98
#  1    1.02
#  dtype: float64,
#  0    4.93
#  1    0.07
#  dtype: float64,
#  0    10.34
#  1     1.66
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    7.87
#  1    0.13
#  dtype: float64,
#  0    4.92
#  1    0.08
#  dtype: float64,
#  0    11.78
#  1     0.22
#  dtype: float64,
#  0    9.94
#  1    0.06
#  dtype: float64,
#  0    13.84
#  1     0.16
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    3.0
#  1    5.0
#  dtype: float64,
#  0    3.19
#  1    0.81
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    5.97
#  1    0.03
#  dtype: float64,
#  0    14.5
#  1     1.5
#  dtype: float64,
#  0    6.93
#  1    0.07
#  dtype: float64,
#  0    15.62
#  1     0.38
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    5.83
#  1    0.17
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    6.79
#  1    0.21
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    14.22
#  1     1.78
#  dtype: float64,
#  0    0.4
#  1    1.6
#  dtype: float64,
#  0    7.26
#  1    0.74
#  dtype: float64,
#  0    15.88
#  1     0.12
#  dtype: float64,
#  0    9.72
#  1    0.28
#  dtype: float64,
#  0    6.85
#  1    1.15
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    3.15
#  1    0.85
#  dtype: float64,
#  0    10.08
#  1     1.92
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    6.99
#  1    0.01
#  dtype: float64,
#  0    7.79
#  1    0.21
#  dtype: float64,
#  0    12.0
#  1     0.0
#  dtype: float64,
#  0    5.63
#  1    0.37
#  dtype: float64,
#  0    5.6
#  1    0.4
#  dtype: float64,
#  0    15.48
#  1     0.52
#  dtype: float64,
#  0    4.536667
#  1    3.463333
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    4.34
#  1    3.66
#  dtype: float64,
#  0    7.95
#  1    0.05
#  dtype: float64,
#  0    6.56
#  1    0.44
#  dtype: float64,
#  0    7.82
#  1    0.18
#  dtype: float64,
#  0    14.08
#  1     1.92
#  dtype: float64,
#  0    6.88
#  1    0.12
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.31
#  1    0.69
#  dtype: float64,
#  0    15.66
#  1     0.34
#  dtype: float64,
#  0    3.761667
#  1    4.238333
#  dtype: float64,
#  0    15.86
#  1     0.14
#  dtype: float64,
#  0    2.74
#  1    2.26
#  dtype: float64,
#  0    7.92
#  1    0.08
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    7.89
#  1    0.11
#  dtype: float64,
#  0    2.29
#  1    0.71
#  dtype: float64,
#  0    6.31
#  1    0.69
#  dtype: float64,
#  0    4.98
#  1    0.02
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    4.46
#  1    3.54
#  dtype: float64,
#  0    2.79
#  1    2.21
#  dtype: float64,
#  0    9.96
#  1    0.04
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    5.92
#  1    0.08
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    7.0
#  1    1.0
#  dtype: float64,
#  0    6.75
#  1    0.25
#  dtype: float64,
#  0    4.63
#  1    0.37
#  dtype: float64,
#  0    6.45
#  1    0.55
#  dtype: float64,
#  0    6.69
#  1    1.31
#  dtype: float64,
#  0    7.62
#  1    0.38
#  dtype: float64,
#  0    7.91
#  1    0.09
#  dtype: float64,
#  0    7.77
#  1    0.23
#  dtype: float64,
#  0    6.74
#  1    0.26
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    15.86
#  1     0.14
#  dtype: float64,
#  0    5.07
#  1    2.93
#  dtype: float64,
#  0    2.93
#  1    0.07
#  dtype: float64,
#  0    3.322833
#  1    1.677167
#  dtype: float64,
#  0    3.99
#  1    0.01
#  dtype: float64,
#  0    12.66
#  1     1.34
#  dtype: float64,
#  0    11.82
#  1     0.18
#  dtype: float64,
#  0    7.0
#  1    0.0
#  dtype: float64,
#  0    7.83
#  1    0.17
#  dtype: float64,
#  0    6.68
#  1    1.32
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    4.99
#  1    0.01
#  dtype: float64,
#  0    7.13
#  1    0.87
#  dtype: float64,
#  0    7.79
#  1    0.21
#  dtype: float64,
#  0    4.96
#  1    0.04
#  dtype: float64,
#  0    6.52
#  1    1.48
#  dtype: float64,
#  0     4.28
#  1    11.72
#  dtype: float64,
#  0    5.47
#  1    1.53
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    6.58
#  1    1.42
#  dtype: float64,
#  0    5.27
#  1    1.73
#  dtype: float64,
#  0    7.74
#  1    2.26
#  dtype: float64,
#  0    9.84
#  1    0.16
#  dtype: float64,
#  0    8.235
#  1    1.765
#  dtype: float64,
#  0    10.0
#  1     0.0
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    13.78
#  1     0.22
#  dtype: float64,
#  0    10.26
#  1     1.74
#  dtype: float64,
#  0    9.88
#  1    0.12
#  dtype: float64,
#  0    3.0
#  1    0.0
#  dtype: float64,
#  0    13.62
#  1     2.38
#  dtype: float64,
#  0    4.634833
#  1    0.365167
#  dtype: float64,
#  0    16.0
#  1     0.0
#  dtype: float64,
#  0    11.62
#  1     0.38
#  dtype: float64,
#  0    15.46
#  1     0.54
#  dtype: float64,
#  0    3.98
#  1    0.02
#  dtype: float64,
#  0    1.94
#  1    0.06
#  dtype: float64,
#  0    13.8
#  1     2.2
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.96
#  1    0.04
#  dtype: float64,
#  0    12.66
#  1     1.34
#  dtype: float64,
#  0    5.58
#  1    2.42
#  dtype: float64,
#  0    14.0
#  1     0.0
#  dtype: float64,
#  0    7.47
#  1    0.53
#  dtype: float64,
#  0    9.74
#  1    4.26
#  dtype: float64,
#  0    8.62
#  1    1.38
#  dtype: float64,
#  0    9.84
#  1    0.16
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    15.34
#  1     0.66
#  dtype: float64,
#  0    9.84
#  1    0.16
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    9.98
#  1    2.02
#  dtype: float64,
#  0    5.41
#  1    1.59
#  dtype: float64,
#  0    7.98
#  1    0.02
#  dtype: float64,
#  0    12.0
#  1     0.0
#  dtype: float64,
#  0    5.29
#  1    0.71
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.76
#  1    0.24
#  dtype: float64,
#  0    16.0
#  1     0.0
#  dtype: float64,
#  0    4.99
#  1    0.01
#  dtype: float64,
#  0    3.9
#  1    0.1
#  dtype: float64,
#  0    7.74
#  1    0.26
#  dtype: float64,
#  0    7.95
#  1    0.05
#  dtype: float64,
#  0    7.9
#  1    0.1
#  dtype: float64,
#  0    11.76
#  1     0.24
#  dtype: float64,
#  0    7.96
#  1    0.04
#  dtype: float64,
#  0    11.44
#  1     0.56
#  dtype: float64,
#  0    7.67
#  1    0.33
#  dtype: float64,
#  0    11.64
#  1     0.36
#  dtype: float64,
#  0    2.09
#  1    1.91
#  dtype: float64,
#  0    14.0
#  1     0.0
#  dtype: float64,
#  0    4.24
#  1    1.76
#  dtype: float64,
#  0    5.74
#  1    0.26
#  dtype: float64,
#  0    13.78
#  1     2.22
#  dtype: float64,
#  0    3.46
#  1    0.54
#  dtype: float64,
#  0    5.94
#  1    0.06
#  dtype: float64,
#  0    10.12
#  1     1.88
#  dtype: float64,
#  0    3.45
#  1    1.55
#  dtype: float64,
#  0    6.0
#  1    2.0
#  dtype: float64,
#  0    6.886833
#  1    1.113167
#  dtype: float64,
#  0    3.99
#  1    0.01
#  dtype: float64,
#  0    12.0
#  1     4.0
#  dtype: float64,
#  0    12.98
#  1     3.02
#  dtype: float64,
#  0    13.78
#  1     0.22
#  dtype: float64,
#  0    7.67
#  1    0.33
#  dtype: float64,
#  0    12.58
#  1     3.42
#  dtype: float64,
#  0    8.4
#  1    5.6
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    16.0
#  1     0.0
#  dtype: float64,
#  0    6.92
#  1    0.08
#  dtype: float64,
#  0    7.87
#  1    0.13
#  dtype: float64,
#  0    7.0
#  1    0.0
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    5.99
#  1    2.01
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    3.15
#  1    3.85
#  dtype: float64,
#  0    6.13
#  1    1.87
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    14.48
#  1     1.52
#  dtype: float64,
#  0    4.82
#  1    0.18
#  dtype: float64,
#  0    7.96
#  1    0.04
#  dtype: float64,
#  0    3.89
#  1    0.11
#  dtype: float64,
#  0    7.98
#  1    0.02
#  dtype: float64,
#  0    14.0
#  1     0.0
#  dtype: float64,
#  0    15.9
#  1     0.1
#  dtype: float64,
#  0    7.99
#  1    0.01
#  dtype: float64,
#  0    1.94
#  1    2.06
#  dtype: float64,
#  0    3.95
#  1    0.05
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    14.2
#  1     1.8
#  dtype: float64,
#  0    13.7
#  1     0.3
#  dtype: float64,
#  0    15.62
#  1     0.38
#  dtype: float64,
#  0    15.96
#  1     0.04
#  dtype: float64,
#  0    15.88
#  1     0.12
#  dtype: float64,
#  0    13.96
#  1     0.04
#  dtype: float64,
#  0    3.81
#  1    0.19
#  dtype: float64,
#  0    13.8
#  1     0.2
#  dtype: float64,
#  0    5.46
#  1    2.54
#  dtype: float64,
#  0    6.78
#  1    9.22
#  dtype: float64,
#  0    6.62
#  1    1.38
#  dtype: float64,
#  0    6.54
#  1    0.46
#  dtype: float64,
#  0    2.08
#  1    0.92
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    3.93
#  1    0.07
#  dtype: float64,
#  0    6.45
#  1    0.55
#  dtype: float64,
#  0    6.64
#  1    1.36
#  dtype: float64,
#  0    14.24
#  1     1.76
#  dtype: float64,
#  0    3.84
#  1    0.16
#  dtype: float64,
#  0    7.72
#  1    0.28
#  dtype: float64,
#  0    4.4
#  1    0.6
#  dtype: float64,
#  0    13.94
#  1     0.06
#  dtype: float64,
#  0    3.64
#  1    4.36
#  dtype: float64,
#  0    5.25
#  1    1.75
#  dtype: float64,
#  0    4.955
#  1    3.045
#  dtype: float64,
#  0    5.973333
#  1    0.026667
#  dtype: float64,
#  0    10.3
#  1     3.7
#  dtype: float64,
#  0    13.52
#  1     0.48
#  dtype: float64,
#  0    3.87
#  1    0.13
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    3.86
#  1    0.14
#  dtype: float64,
#  0    15.6
#  1     0.4
#  dtype: float64,
#  0    6.92
#  1    0.08
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    7.16
#  1    0.84
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    6.21
#  1    0.79
#  dtype: float64,
#  0    15.92
#  1     0.08
#  dtype: float64,
#  0    5.65
#  1    2.35
#  dtype: float64,
#  0    1.98
#  1    0.02
#  dtype: float64,
#  0    7.63
#  1    0.37
#  dtype: float64,
#  0    6.73
#  1    1.27
#  dtype: float64,
#  0    15.8
#  1     0.2
#  dtype: float64,
#  0    7.28
#  1    0.72
#  dtype: float64,
#  0    4.87
#  1    0.13
#  dtype: float64,
#  0    1.11
#  1    0.89
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    3.14
#  1    1.86
#  dtype: float64,
#  0    6.88
#  1    0.12
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    6.16
#  1    1.84
#  dtype: float64,
#  0    6.05
#  1    0.95
#  dtype: float64,
#  0    14.0
#  1     0.0
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    0.98
#  1    0.02
#  dtype: float64,
#  0    6.03
#  1    1.97
#  dtype: float64,
#  0    0.8
#  1    0.2
#  dtype: float64,
#  0    13.84
#  1     0.16
#  dtype: float64,
#  0    3.94
#  1    0.06
#  dtype: float64,
#  0    1.98
#  1    0.02
#  dtype: float64,
#  0    5.22
#  1    0.78
#  dtype: float64,
#  0    7.99
#  1    0.01
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    4.67
#  1    0.33
#  dtype: float64,
#  0    16.0
#  1     0.0
#  dtype: float64,
#  0    5.93
#  1    0.07
#  dtype: float64,
#  0    7.7
#  1    0.3
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    13.94
#  1     0.06
#  dtype: float64,
#  0    14.54
#  1     1.46
#  dtype: float64,
#  0    4.23
#  1    0.77
#  dtype: float64,
#  0    11.98
#  1     0.02
#  dtype: float64,
#  0    1.93
#  1    0.07
#  dtype: float64,
#  0    6.06
#  1    0.94
#  dtype: float64,
#  0    5.59
#  1    2.41
#  dtype: float64,
#  0    5.98
#  1    0.02
#  dtype: float64,
#  0    7.3
#  1    0.7
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    4.95
#  1    0.05
#  dtype: float64,
#  0    7.78
#  1    0.22
#  dtype: float64,
#  0    9.84
#  1    0.16
#  dtype: float64,
#  0    7.0
#  1    1.0
#  dtype: float64,
#  0    6.92
#  1    0.08
#  dtype: float64,
#  0    6.12
#  1    1.88
#  dtype: float64,
#  0    15.7
#  1     0.3
#  dtype: float64,
#  0    4.84
#  1    0.16
#  dtype: float64,
#  0    5.9
#  1    0.1
#  dtype: float64,
#  0    7.16
#  1    0.84
#  dtype: float64,
#  0    5.27
#  1    1.73
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    3.98
#  1    0.02
#  dtype: float64,
#  0    7.73
#  1    0.27
#  dtype: float64,
#  0    3.92
#  1    0.08
#  dtype: float64,
#  0    3.97
#  1    1.03
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    13.92
#  1     0.08
#  dtype: float64,
#  0    15.04
#  1     0.96
#  dtype: float64,
#  0    4.46
#  1    3.54
#  dtype: float64,
#  0    11.66
#  1     0.34
#  dtype: float64,
#  0    5.84
#  1    4.16
#  dtype: float64,
#  0    3.47
#  1    0.53
#  dtype: float64,
#  0    9.82
#  1    0.18
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    3.0
#  1    0.0
#  dtype: float64,
#  0    5.99
#  1    0.01
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    9.92
#  1    0.08
#  dtype: float64,
#  0    5.096833
#  1    2.903167
#  dtype: float64,
#  0    2.17
#  1    3.83
#  dtype: float64,
#  0    10.82
#  1     3.18
#  dtype: float64,
#  0    11.98
#  1     0.02
#  dtype: float64,
#  0    7.05
#  1    0.95
#  dtype: float64,
#  0    4.98
#  1    0.02
#  dtype: float64,
#  0    2.09
#  1    0.91
#  dtype: float64,
#  0    7.28
#  1    0.72
#  dtype: float64,
#  0    15.86
#  1     0.14
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    6.36
#  1    5.64
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    6.94
#  1    0.06
#  dtype: float64,
#  0    0.95
#  1    0.05
#  dtype: float64,
#  0    15.98
#  1     0.02
#  dtype: float64,
#  0    6.86
#  1    1.14
#  dtype: float64,
#  0    4.98
#  1    0.02
#  dtype: float64,
#  0    14.38
#  1     1.62
#  dtype: float64,
#  0    14.14
#  1     1.86
#  dtype: float64,
#  0    10.42
#  1     3.58
#  dtype: float64,
#  0    4.33
#  1    0.67
#  dtype: float64,
#  0    7.02
#  1    0.98
#  dtype: float64,
#  0    5.47
#  1    0.53
#  dtype: float64,
#  0    4.95
#  1    0.05
#  dtype: float64,
#  0    6.85
#  1    0.15
#  dtype: float64,
#  0    4.99
#  1    0.01
#  dtype: float64,
#  0    8.02
#  1    1.98
#  dtype: float64,
#  0    3.0
#  1    0.0
#  dtype: float64,
#  0    2.98
#  1    0.02
#  dtype: float64,
#  0    11.92
#  1     0.08
#  dtype: float64,
#  0    6.28
#  1    0.72
#  dtype: float64,
#  0    4.27
#  1    3.73
#  dtype: float64,
#  0    5.02
#  1    2.98
#  dtype: float64,
#  0    1.99
#  1    0.01
#  dtype: float64,
#  0    5.11
#  1    0.89
#  dtype: float64,
#  0    15.82
#  1     0.18
#  dtype: float64,
#  0    13.54
#  1     2.46
#  dtype: float64,
#  0    6.47
#  1    0.53
#  dtype: float64,
#  0    7.69
#  1    0.31
#  dtype: float64,
#  0    6.45
#  1    1.55
#  dtype: float64,
#  0    14.0
#  1     2.0
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    7.91
#  1    0.09
#  dtype: float64,
#  0    4.41
#  1    1.59
#  dtype: float64,
#  0    0.64
#  1    1.36
#  dtype: float64,
#  0    3.62
#  1    0.38
#  dtype: float64,
#  0    4.81
#  1    3.19
#  dtype: float64,
#  0    6.88
#  1    0.12
#  dtype: float64,
#  0    6.98
#  1    0.02
#  dtype: float64,
#  0    3.41
#  1    1.59
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    3.538
#  1    1.462
#  dtype: float64,
#  0    6.95
#  1    0.05
#  dtype: float64,
#  0    13.94
#  1     0.06
#  dtype: float64,
#  0    7.95
#  1    0.05
#  dtype: float64,
#  0    7.93
#  1    0.07
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    11.94
#  1     2.06
#  dtype: float64,
#  0    15.8
#  1     0.2
#  dtype: float64,
#  0    7.91
#  1    0.09
#  dtype: float64,
#  0    14.68
#  1     1.32
#  dtype: float64,
#  0    6.52
#  1    1.48
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    15.74
#  1     0.26
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    9.56
#  1    2.44
#  dtype: float64,
#  0    11.38
#  1     2.62
#  dtype: float64,
#  0    14.44
#  1     1.56
#  dtype: float64,
#  0    12.84
#  1     3.16
#  dtype: float64,
#  0    4.3
#  1    3.7
#  dtype: float64,
#  0    11.64
#  1     0.36
#  dtype: float64,
#  0    6.31
#  1    1.69
#  dtype: float64,
#  0    6.64
#  1    0.36
#  dtype: float64,
#  0    5.88
#  1    0.12
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    5.96
#  1    0.04
#  dtype: float64,
#  0    6.86
#  1    1.14
#  dtype: float64,
#  0    7.63
#  1    0.37
#  dtype: float64,
#  0    0.99
#  1    0.01
#  dtype: float64,
#  0    1.93
#  1    0.07
#  dtype: float64,
#  0    6.02
#  1    1.98
#  dtype: float64,
#  0    5.79
#  1    1.21
#  dtype: float64,
#  0    10.0
#  1     0.0
#  dtype: float64,
#  0    7.98
#  1    0.02
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    8.76
#  1    1.24
#  dtype: float64,
#  0    14.58
#  1     1.42
#  dtype: float64,
#  0    6.78
#  1    1.22
#  dtype: float64,
#  0    12.74
#  1     3.26
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    15.84
#  1     0.16
#  dtype: float64,
#  0    0.99
#  1    0.01
#  dtype: float64,
#  0    3.85
#  1    1.15
#  dtype: float64,
#  0    7.86
#  1    0.14
#  dtype: float64,
#  0    7.74
#  1    0.26
#  dtype: float64,
#  0    5.31
#  1    2.69
#  dtype: float64,
#  0    9.34
#  1    6.66
#  dtype: float64,
#  0    5.72
#  1    2.28
#  dtype: float64,
#  0    10.28
#  1     1.72
#  dtype: float64,
#  0    4.14
#  1    1.86
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    4.62
#  1    0.38
#  dtype: float64,
#  0    7.13
#  1    0.87
#  dtype: float64,
#  0    4.8
#  1    0.2
#  dtype: float64,
#  0    6.89
#  1    0.11
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    13.78
#  1     0.22
#  dtype: float64,
#  0    7.84
#  1    0.16
#  dtype: float64,
#  0    2.84
#  1    0.16
#  dtype: float64,
#  0    11.82
#  1     0.18
#  dtype: float64,
#  0    9.72
#  1    0.28
#  dtype: float64,
#  0    6.67
#  1    1.33
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    3.76
#  1    2.24
#  dtype: float64,
#  0    11.38
#  1     4.62
#  dtype: float64,
#  0    5.447667
#  1    1.552333
#  dtype: float64,
#  0    3.95
#  1    1.05
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    3.74
#  1    1.26
#  dtype: float64,
#  0    7.91
#  1    0.09
#  dtype: float64,
#  0    3.88
#  1    3.12
#  dtype: float64,
#  0    14.0
#  1     2.0
#  dtype: float64,
#  0    5.74
#  1    2.26
#  dtype: float64,
#  0    7.23
#  1    0.77
#  dtype: float64,
#  0    4.59
#  1    1.41
#  dtype: float64,
#  0    6.66
#  1    0.34
#  dtype: float64,
#  0    6.16
#  1    1.84
#  dtype: float64,
#  0    3.92
#  1    0.08
#  dtype: float64,
#  0    5.9
#  1    0.1
#  dtype: float64,
#  0    14.115
#  1     1.885
#  dtype: float64,
#  0    6.89
#  1    1.11
#  dtype: float64,
#  0    12.02
#  1     1.98
#  dtype: float64,
#  0    6.65
#  1    0.35
#  dtype: float64,
#  0    4.35
#  1    0.65
#  dtype: float64,
#  0    6.59
#  1    1.41
#  dtype: float64,
#  0    9.74
#  1    0.26
#  dtype: float64,
#  0    14.44
#  1     1.56
#  dtype: float64,
#  0    4.97
#  1    0.03
#  dtype: float64,
#  0    6.47
#  1    1.53
#  dtype: float64,
#  0    12.06
#  1     1.94
#  dtype: float64,
#  0    3.88
#  1    2.12
#  dtype: float64,
#  0    6.99
#  1    0.01
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    1.25
#  1    0.75
#  dtype: float64,
#  0    4.88
#  1    0.12
#  dtype: float64,
#  0    2.6
#  1    0.4
#  dtype: float64,
#  0    7.69
#  1    0.31
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    3.59
#  1    0.41
#  dtype: float64,
#  0    16.0
#  1     0.0
#  dtype: float64,
#  0    9.92
#  1    0.08
#  dtype: float64,
#  0    5.89
#  1    2.11
#  dtype: float64,
#  0    7.81
#  1    0.19
#  dtype: float64,
#  0    14.82
#  1     1.18
#  dtype: float64,
#  0    13.92
#  1     0.08
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    6.586667
#  1    1.413333
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    11.98
#  1     2.02
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    3.94
#  1    0.06
#  dtype: float64,
#  0    14.0
#  1     0.0
#  dtype: float64,
#  0    7.54
#  1    0.46
#  dtype: float64,
#  0    5.63
#  1    1.37
#  dtype: float64,
#  0    7.32
#  1    0.68
#  dtype: float64,
#  0    7.0
#  1    0.0
#  dtype: float64,
#  0    4.89
#  1    0.11
#  dtype: float64,
#  0    12.2
#  1     3.8
#  dtype: float64,
#  0    7.11
#  1    0.89
#  dtype: float64,
#  0    7.73
#  1    0.27
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    10.0
#  1     0.0
#  dtype: float64,
#  0    6.2
#  1    1.8
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    13.86
#  1     0.14
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    5.54
#  1    2.46
#  dtype: float64,
#  0    11.66
#  1     0.34
#  dtype: float64,
#  0    6.82
#  1    1.18
#  dtype: float64,
#  0    14.08
#  1     1.92
#  dtype: float64,
#  0    5.32
#  1    2.68
#  dtype: float64,
#  0    12.12
#  1     1.88
#  dtype: float64,
#  0    10.0
#  1     0.0
#  dtype: float64,
#  0    10.0
#  1     0.0
#  dtype: float64,
#  0    3.75
#  1    4.25
#  dtype: float64,
#  0    2.75
#  1    1.25
#  dtype: float64,
#  0    7.78
#  1    2.22
#  dtype: float64,
#  0    14.6
#  1     1.4
#  dtype: float64,
#  0    4.87
#  1    0.13
#  dtype: float64,
#  0    0.98
#  1    0.02
#  dtype: float64,
#  0    3.95
#  1    0.05
#  dtype: float64,
#  0    10.18
#  1     1.82
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    5.74
#  1    1.26
#  dtype: float64,
#  0    3.83
#  1    0.17
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.98
#  1    0.02
#  dtype: float64,
#  0    9.74
#  1    2.26
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    7.41
#  1    0.59
#  dtype: float64,
#  0    3.018333
#  1    2.981667
#  dtype: float64,
#  0    15.46
#  1     0.54
#  dtype: float64,
#  0    6.11
#  1    0.89
#  dtype: float64,
#  0    7.66
#  1    0.34
#  dtype: float64,
#  0    13.94
#  1     2.06
#  dtype: float64,
#  0    6.42
#  1    1.58
#  dtype: float64,
#  0    4.35
#  1    3.65
#  dtype: float64,
#  0    13.86
#  1     0.14
#  dtype: float64,
#  0    6.03
#  1    0.97
#  dtype: float64,
#  0    4.98
#  1    0.02
#  dtype: float64,
#  0    7.06
#  1    0.94
#  dtype: float64,
#  0    5.96
#  1    0.04
#  dtype: float64,
#  0    6.59
#  1    1.41
#  dtype: float64,
#  0    4.86
#  1    0.14
#  dtype: float64,
#  0    3.23
#  1    4.77
#  dtype: float64,
#  0    7.06
#  1    0.94
#  dtype: float64,
#  0    7.16
#  1    0.84
#  dtype: float64,
#  0    8.5
#  1    1.5
#  dtype: float64,
#  0    9.96
#  1    0.04
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    4.75
#  1    2.25
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    7.99
#  1    0.01
#  dtype: float64,
#  0    4.71
#  1    0.29
#  dtype: float64,
#  0    10.84
#  1     3.16
#  dtype: float64,
#  0    9.64
#  1    0.36
#  dtype: float64,
#  0    7.33
#  1    0.67
#  dtype: float64,
#  0    3.87
#  1    0.13
#  dtype: float64,
#  0    5.98
#  1    0.02
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    6.3475
#  1    0.6525
#  dtype: float64,
#  0    1.26
#  1    0.74
#  dtype: float64,
#  0    13.24
#  1     0.76
#  dtype: float64,
#  0    1.82
#  1    3.18
#  dtype: float64,
#  0    4.4
#  1    0.6
#  dtype: float64,
#  0    3.83
#  1    0.17
#  dtype: float64,
#  0    12.4
#  1     3.6
#  dtype: float64,
#  0    12.0
#  1     4.0
#  dtype: float64,
#  0    4.91
#  1    2.09
#  dtype: float64,
#  0    10.04
#  1     1.96
#  dtype: float64,
#  0    2.97
#  1    0.03
#  dtype: float64,
#  0    7.17
#  1    0.83
#  dtype: float64,
#  0    4.51
#  1    1.49
#  dtype: float64,
#  0    5.46
#  1    2.54
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    14.0
#  1     0.0
#  dtype: float64,
#  0    7.83
#  1    0.17
#  dtype: float64,
#  0    4.68
#  1    0.32
#  dtype: float64,
#  0    8.12
#  1    3.88
#  dtype: float64,
#  0    5.15
#  1    2.85
#  dtype: float64,
#  0    11.2
#  1     4.8
#  dtype: float64,
#  0    13.22
#  1     2.78
#  dtype: float64,
#  0    7.0
#  1    1.0
#  dtype: float64,
#  0    7.27
#  1    0.73
#  dtype: float64,
#  0    15.86
#  1     0.14
#  dtype: float64,
#  0    3.91
#  1    0.09
#  dtype: float64,
#  0    9.86
#  1    0.14
#  dtype: float64,
#  0    3.26
#  1    0.74
#  dtype: float64,
#  0    2.72
#  1    0.28
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    14.28
#  1     1.72
#  dtype: float64,
#  0    4.99
#  1    0.01
#  dtype: float64,
#  0    11.5
#  1     2.5
#  dtype: float64,
#  0    7.05
#  1    0.95
#  dtype: float64,
#  0    7.79
#  1    0.21
#  dtype: float64,
#  0    6.46
#  1    1.54
#  dtype: float64,
#  0    3.245
#  1    1.755
#  dtype: float64,
#  0    4.86
#  1    3.14
#  dtype: float64,
#  0    7.99
#  1    0.01
#  dtype: float64,
#  0    6.18
#  1    0.82
#  dtype: float64,
#  0    6.38
#  1    3.62
#  dtype: float64,
#  0    15.36
#  1     0.64
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    7.76
#  1    0.24
#  dtype: float64,
#  0    15.84
#  1     0.16
#  dtype: float64,
#  0    6.08
#  1    1.92
#  dtype: float64,
#  0    7.12
#  1    0.88
#  dtype: float64,
#  0    4.26
#  1    5.74
#  dtype: float64,
#  0    5.94
#  1    0.06
#  dtype: float64,
#  0    6.85
#  1    1.15
#  dtype: float64,
#  0    6.39
#  1    0.61
#  dtype: float64,
#  0    5.0
#  1    0.0
#  dtype: float64,
#  0    10.52
#  1     5.48
#  dtype: float64,
#  0    4.6
#  1    3.4
#  dtype: float64,
#  0    4.99
#  1    2.01
#  dtype: float64,
#  0    11.12
#  1     4.88
#  dtype: float64,
#  0    7.35
#  1    0.65
#  dtype: float64,
#  0    13.36
#  1     2.64
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    10.12
#  1     3.88
#  dtype: float64,
#  0    7.96
#  1    0.04
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    7.68
#  1    0.32
#  dtype: float64,
#  0    6.138333
#  1    1.861667
#  dtype: float64,
#  0    8.38
#  1    1.62
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    4.7
#  1    2.3
#  dtype: float64,
#  0    4.73
#  1    3.27
#  dtype: float64,
#  0    13.96
#  1     2.04
#  dtype: float64,
#  0    15.96
#  1     0.04
#  dtype: float64,
#  0    0.98
#  1    0.02
#  dtype: float64,
#  0    0.95
#  1    0.05
#  dtype: float64,
#  0    5.24
#  1    0.76
#  dtype: float64,
#  0    7.6
#  1    0.4
#  dtype: float64,
#  0    5.81
#  1    0.19
#  dtype: float64,
#  0    6.21
#  1    1.79
#  dtype: float64,
#  0    7.0
#  1    0.0
#  dtype: float64,
#  0    6.66
#  1    0.34
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.0
#  1    0.0
#  dtype: float64,
#  0    2.92
#  1    0.08
#  dtype: float64,
#  0    9.96
#  1    0.04
#  dtype: float64,
#  0    7.64
#  1    0.36
#  dtype: float64,
#  0    3.95
#  1    0.05
#  dtype: float64,
#  0    6.09
#  1    1.91
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    5.0
#  1    0.0
#  dtype: float64,
#  0    3.47
#  1    2.53
#  dtype: float64,
#  0    6.99
#  1    0.01
#  dtype: float64,
#  0    4.18
#  1    1.82
#  dtype: float64,
#  0    3.28
#  1    1.72
#  dtype: float64,
#  0    6.99
#  1    0.01
#  dtype: float64,
#  0    4.73
#  1    3.27
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    2.78
#  1    5.22
#  dtype: float64,
#  0    15.9
#  1     0.1
#  dtype: float64,
#  0    6.84
#  1    0.16
#  dtype: float64,
#  0    5.98
#  1    0.02
#  dtype: float64,
#  0    5.31
#  1    2.69
#  dtype: float64,
#  0    5.99
#  1    0.01
#  dtype: float64,
#  0    12.72
#  1     3.28
#  dtype: float64,
#  0    11.54
#  1     4.46
#  dtype: float64,
#  0    7.66
#  1    0.34
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    15.96
#  1     0.04
#  dtype: float64,
#  0    5.96
#  1    0.04
#  dtype: float64,
#  0    7.96
#  1    0.04
#  dtype: float64,
#  0    5.76
#  1    1.24
#  dtype: float64,
#  0    8.76
#  1    1.24
#  dtype: float64,
#  0    7.86
#  1    0.14
#  dtype: float64,
#  0    14.02
#  1     1.98
#  dtype: float64,
#  0    14.338667
#  1     1.661333
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    13.38
#  1     2.62
#  dtype: float64,
#  0    11.98
#  1     0.02
#  dtype: float64,
#  0    15.48
#  1     0.52
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    10.0
#  1     0.0
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    3.0
#  1    0.0
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    8.72
#  1    3.28
#  dtype: float64,
#  0    12.52
#  1     3.48
#  dtype: float64,
#  0    7.3775
#  1    0.6225
#  dtype: float64,
#  0    7.05
#  1    0.95
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    7.67
#  1    0.33
#  dtype: float64,
#  0    5.82
#  1    0.18
#  dtype: float64,
#  0    5.98
#  1    0.02
#  dtype: float64,
#  0    4.715167
#  1    2.284833
#  dtype: float64,
#  0    4.82
#  1    5.18
#  dtype: float64,
#  0    6.35
#  1    0.65
#  dtype: float64,
#  0    2.69
#  1    3.31
#  dtype: float64,
#  0    6.53
#  1    0.47
#  dtype: float64,
#  0    14.14
#  1     1.86
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    7.8
#  1    0.2
#  dtype: float64,
#  0    3.34
#  1    3.66
#  dtype: float64,
#  0    7.39
#  1    0.61
#  dtype: float64,
#  0    10.7
#  1     5.3
#  dtype: float64,
#  0    15.82
#  1     0.18
#  dtype: float64,
#  0    3.96
#  1    0.04
#  dtype: float64,
#  0    4.303905
#  1    3.696095
#  dtype: float64,
#  0    6.99
#  1    1.01
#  dtype: float64,
#  0    13.76
#  1     0.24
#  dtype: float64,
#  0    7.0
#  1    0.0
#  dtype: float64,
#  0    7.92
#  1    2.08
#  dtype: float64,
#  0    4.0
#  1    3.0
#  dtype: float64,
#  0    13.54
#  1     0.46
#  dtype: float64,
#  0    7.74
#  1    2.26
#  dtype: float64,
#  0    0.92
#  1    0.08
#  dtype: float64,
#  0    5.97
#  1    0.03
#  dtype: float64,
#  0    6.41
#  1    1.59
#  dtype: float64,
#  0    7.84
#  1    0.16
#  dtype: float64,
#  0    3.0
#  1    0.0
#  dtype: float64,
#  0    13.74
#  1     0.26
#  dtype: float64,
#  0    5.86
#  1    2.14
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    9.62
#  1    6.38
#  dtype: float64,
#  0    7.54
#  1    0.46
#  dtype: float64,
#  0    16.0
#  1     0.0
#  dtype: float64,
#  0    8.64
#  1    1.36
#  dtype: float64,
#  0    7.77
#  1    0.23
#  dtype: float64,
#  0    2.92
#  1    0.08
#  dtype: float64,
#  0    5.39
#  1    1.61
#  dtype: float64,
#  0    13.704167
#  1     0.295833
#  dtype: float64,
#  0    7.65
#  1    0.35
#  dtype: float64,
#  0    5.8
#  1    0.2
#  dtype: float64,
#  0    4.79
#  1    2.21
#  dtype: float64,
#  0    5.77
#  1    1.23
#  dtype: float64,
#  0    1.94
#  1    0.06
#  dtype: float64,
#  0    11.46
#  1     0.54
#  dtype: float64,
#  0    9.92
#  1    0.08
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    7.81
#  1    0.19
#  dtype: float64,
#  0    2.92
#  1    0.08
#  dtype: float64,
#  0    4.8
#  1    1.2
#  dtype: float64,
#  0    7.43
#  1    0.57
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.86
#  1    0.14
#  dtype: float64,
#  0    12.0
#  1     0.0
#  dtype: float64,
#  0    6.92
#  1    0.08
#  dtype: float64,
#  0    7.77
#  1    0.23
#  dtype: float64,
#  0    5.76
#  1    1.24
#  dtype: float64,
#  0    14.12
#  1     1.88
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.99
#  1    0.01
#  dtype: float64,
#  0    6.99
#  1    0.01
#  dtype: float64,
#  0    15.22
#  1     0.78
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    5.7
#  1    0.3
#  dtype: float64,
#  0    3.25
#  1    2.75
#  dtype: float64,
#  0    15.4
#  1     0.6
#  dtype: float64,
#  0    6.29
#  1    1.71
#  dtype: float64,
#  0    5.52
#  1    0.48
#  dtype: float64,
#  0    4.95
#  1    0.05
#  dtype: float64,
#  0    6.965
#  1    1.035
#  dtype: float64,
#  0    7.58
#  1    0.42
#  dtype: float64,
#  0    5.81
#  1    2.19
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    3.82
#  1    2.18
#  dtype: float64,
#  0    1.47
#  1    1.53
#  dtype: float64,
#  0    14.48
#  1     1.52
#  dtype: float64,
#  0    6.28
#  1    1.72
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    6.98
#  1    7.02
#  dtype: float64,
#  0    3.85
#  1    0.15
#  dtype: float64,
#  0    4.26
#  1    3.74
#  dtype: float64,
#  0    3.44
#  1    1.56
#  dtype: float64,
#  0    2.35
#  1    0.65
#  dtype: float64,
#  0    6.65
#  1    0.35
#  dtype: float64,
#  0    6.24
#  1    0.76
#  dtype: float64,
#  0    4.68
#  1    1.32
#  dtype: float64,
#  0    12.14
#  1     3.86
#  dtype: float64,
#  0    10.42
#  1     1.58
#  dtype: float64,
#  0    4.86
#  1    0.14
#  dtype: float64,
#  0    7.94
#  1    0.06
#  dtype: float64,
#  0    6.64
#  1    0.36
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    7.31
#  1    0.69
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    1.97
#  1    0.03
#  dtype: float64,
#  0    7.1
#  1    0.9
#  dtype: float64,
#  0    6.09
#  1    0.91
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    4.44
#  1    3.56
#  dtype: float64,
#  0    1.9
#  1    0.1
#  dtype: float64,
#  0    6.28
#  1    0.72
#  dtype: float64,
#  0    5.58
#  1    1.42
#  dtype: float64,
#  0    4.97
#  1    0.03
#  dtype: float64,
#  0    3.96
#  1    0.04
#  dtype: float64,
#  0    5.27
#  1    0.73
#  dtype: float64,
#  0    9.88
#  1    0.12
#  dtype: float64,
#  0    4.98
#  1    0.02
#  dtype: float64,
#  0    14.16
#  1     1.84
#  dtype: float64,
#  0    7.82
#  1    0.18
#  dtype: float64,
#  0    5.13
#  1    0.87
#  dtype: float64,
#  0    12.0
#  1     0.0
#  dtype: float64,
#  0    6.32
#  1    1.68
#  dtype: float64,
#  0    7.85
#  1    0.15
#  dtype: float64,
#  0    7.798333
#  1    0.201667
#  dtype: float64,
#  0    15.9
#  1     0.1
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    2.99
#  1    0.01
#  dtype: float64,
#  0    7.96
#  1    0.04
#  dtype: float64,
#  0    7.03
#  1    0.97
#  dtype: float64,
#  0    6.57
#  1    1.43
#  dtype: float64,
#  0    11.86
#  1     0.14
#  dtype: float64,
#  0    13.96
#  1     0.04
#  dtype: float64,
#  0    12.72
#  1     1.28
#  dtype: float64,
#  0    13.9
#  1     0.1
#  dtype: float64,
#  0    6.86
#  1    0.14
#  dtype: float64,
#  0    8.4
#  1    5.6
#  dtype: float64,
#  0    3.99
#  1    0.01
#  dtype: float64,
#  0    13.12
#  1     2.88
#  dtype: float64,
#  0    12.76
#  1     3.24
#  dtype: float64,
#  0    7.87
#  1    0.13
#  dtype: float64,
#  0    4.95
#  1    3.05
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    15.54
#  1     0.46
#  dtype: float64,
#  0    4.66
#  1    0.34
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    13.9
#  1     0.1
#  dtype: float64,
#  0    7.92
#  1    0.08
#  dtype: float64,
#  0    5.78
#  1    2.22
#  dtype: float64,
#  0    6.85
#  1    1.15
#  dtype: float64,
#  0    2.564286
#  1    3.435714
#  dtype: float64,
#  0    2.12
#  1    0.88
#  dtype: float64,
#  0    13.78
#  1     0.22
#  dtype: float64,
#  0    15.84
#  1     0.16
#  dtype: float64,
#  0    6.98
#  1    0.02
#  dtype: float64,
#  0    6.5
#  1    0.5
#  dtype: float64,
#  0    6.32
#  1    1.68
#  dtype: float64,
#  0    3.85
#  1    2.15
#  dtype: float64,
#  0    7.59
#  1    0.41
#  dtype: float64,
#  0    8.14
#  1    3.86
#  dtype: float64,
#  0    3.79
#  1    0.21
#  dtype: float64,
#  0    7.87
#  1    0.13
#  dtype: float64,
#  0    9.98
#  1    0.02
#  dtype: float64,
#  0    5.98
#  1    2.02
#  dtype: float64,
#  0    9.5
#  1    0.5
#  dtype: float64,
#  0    2.98
#  1    0.02
#  dtype: float64,
#  0    13.92
#  1     0.08
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    15.68
#  1     0.32
#  dtype: float64,
#  0    7.89
#  1    0.11
#  dtype: float64,
#  0    7.12
#  1    0.88
#  dtype: float64,
#  0    7.0
#  1    0.0
#  dtype: float64,
#  0    13.48
#  1     0.52
#  dtype: float64,
#  0    4.99
#  1    0.01
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    3.92
#  1    0.08
#  dtype: float64,
#  0    7.4
#  1    0.6
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    7.08
#  1    0.92
#  dtype: float64,
#  0    6.98
#  1    0.02
#  dtype: float64,
#  0    2.23
#  1    0.77
#  dtype: float64,
#  0    11.82
#  1     0.18
#  dtype: float64,
#  0    6.48
#  1    1.52
#  dtype: float64,
#  0    1.15
#  1    0.85
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.72
#  1    0.28
#  dtype: float64,
#  0    4.91
#  1    0.09
#  dtype: float64,
#  0    15.96
#  1     0.04
#  dtype: float64,
#  0    11.9
#  1     0.1
#  dtype: float64,
#  0    4.98
#  1    0.02
#  dtype: float64,
#  0    7.82
#  1    0.18
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    5.541667
#  1    2.458333
#  dtype: float64,
#  0    5.0
#  1    0.0
#  dtype: float64,
#  0    12.92
#  1     1.08
#  dtype: float64,
#  0    6.23
#  1    1.77
#  dtype: float64,
#  0    2.95
#  1    0.05
#  dtype: float64,
#  0    11.46
#  1     0.54
#  dtype: float64,
#  0    7.24
#  1    0.76
#  dtype: float64,
#  0    6.86
#  1    0.14
#  dtype: float64,
#  0    4.25
#  1    3.75
#  dtype: float64,
#  0    12.96
#  1     3.04
#  dtype: float64,
#  0    5.85
#  1    1.15
#  dtype: float64,
#  0    4.04
#  1    0.96
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    12.98
#  1     3.02
#  dtype: float64,
#  0    6.0
#  1    0.0
#  dtype: float64,
#  0    4.31
#  1    0.69
#  dtype: float64,
#  0    6.99
#  1    0.01
#  dtype: float64,
#  0    0.93
#  1    0.07
#  dtype: float64,
#  0    7.23
#  1    0.77
#  dtype: float64,
#  0    7.93
#  1    0.07
#  dtype: float64,
#  0    5.46
#  1    2.54
#  dtype: float64,
#  0    15.42
#  1     0.58
#  dtype: float64,
#  0    9.82
#  1    2.18
#  dtype: float64,
#  0    3.23
#  1    4.77
#  dtype: float64,
#  0    4.015
#  1    1.985
#  dtype: float64,
#  0    6.69
#  1    1.31
#  dtype: float64,
#  0    13.96
#  1     2.04
#  dtype: float64,
#  0    11.98
#  1     0.02
#  dtype: float64,
#  0    4.44
#  1    0.56
#  dtype: float64,
#  0    7.97
#  1    0.03
#  dtype: float64,
#  0    4.96
#  1    0.04
#  dtype: float64,
#  0    3.0
#  1    0.0
#  dtype: float64,
#  0    15.86
#  1     0.14
#  dtype: float64,
#  0    14.22
#  1     1.78
#  dtype: float64,
#  0    1.0
#  1    0.0
#  dtype: float64,
#  0    4.2
#  1    0.8
#  dtype: float64,
#  0    6.47
#  1    0.53
#  dtype: float64,
#  0    3.93
#  1    0.07
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    7.14
#  1    0.86
#  dtype: float64,
#  0    11.46
#  1     0.54
#  dtype: float64,
#  0    12.8
#  1     1.2
#  dtype: float64,
#  0    3.86
#  1    0.14
#  dtype: float64,
#  0    7.07
#  1    0.93
#  dtype: float64,
#  0    6.69
#  1    0.31
#  dtype: float64,
#  0    1.88
#  1    3.12
#  dtype: float64,
#  0    5.7545
#  1    1.2455
#  dtype: float64,
#  0    6.14
#  1    1.86
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    6.38
#  1    1.62
#  dtype: float64,
#  0    4.4
#  1    0.6
#  dtype: float64,
#  0    4.42
#  1    1.58
#  dtype: float64,
#  0    4.0
#  1    0.0
#  dtype: float64,
#  0    11.751
#  1     0.249
#  dtype: float64,
#  0    10.86
#  1     1.14
#  dtype: float64,
#  0    7.14
#  1    0.86
#  dtype: float64,
#  0    6.53
#  1    1.47
#  dtype: float64,
#  0    2.0
#  1    0.0
#  dtype: float64,
#  0    13.96
#  1     0.04
#  dtype: float64,
#  0    9.8
#  1    0.2
#  dtype: float64,
#  0    6.36
#  1    1.64
#  dtype: float64,
#  0    4.86
#  1    0.14
#  dtype: float64,
#  0    5.84
#  1    0.16
#  dtype: float64,
#  0    5.35
#  1    0.65
#  dtype: float64,
#  0    7.5
#  1    0.5
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    5.5
#  1    0.5
#  dtype: float64,
#  0    13.98
#  1     0.02
#  dtype: float64,
#  0    4.8
#  1    0.2
#  dtype: float64,
#  0    8.0
#  1    0.0
#  dtype: float64,
#  0    0.0
#  1    0.0
#  dtype: float64,
#  0    7.28
#  1    0.72
#  dtype: float64,
#  ...]

# %%
neighbors = [ca.w.neighbors[x] for x in ca.X_train.index]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import ExtraTreeClassifier

# %%
df.columns
# Out:
# Index(['bijeenkomstfunctie', 'gezondheidszorgfunctie', 'industriefunctie',
#        'kantoorfunctie', 'logiesfunctie', 'onderwijsfunctie', 'sportfunctie',
#        'winkelfunctie', 'woonfunctie', 'oppervlakteVerblijfsobject',
#        'inwoner_g', 'geboorte_g', 'inw_014_g', 'inw_1524_g', 'inw_2544_g',
#        'inw_4564_g', 'inw_65_g', 'p_western_g', 'p_nonWestern_g',
#        'p_buyhouses_g', 'p_rentals_g', 'p_socialHousing_g', 'medianIncome_g',
#        'avg_electricity_g', 'avg_gas_g', 'p_benefits_g', 'afs_haprak_g',
#        'afs_ziek_g', 'afs_superm_g', 'afs_vo_g', 'afs_oprit_g', 'afs_train_g',
#        'afs_transit_g', 'p_buildBefore2000_g', 'p_buildAfter2000_g',
#        'mean_WOZ', 'PLaagste40Inkomen', 'PHoogste20Inkomen', 'C28992R100',
#        'geometry', 'y', 'BU_CODE'],
#       dtype='object')

# %%
X = df[df.columns[:-4]]

# %%
Y = df.y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=2)

# %%
# clf = RandomForestClassifier(max_depth=4, random_state=0, n_estimators = 1000, min_samples_split = 3)
clf = DecisionTreeClassifier(max_depth=4, random_state=0)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=0)

# %%
X_pred = clf.predict_proba(X)

# %%
X_pred = pd.DataFrame(X_pred[:,1])
X_t_pred = X_pred.loc[X_test.index]

# %%
def calc_score
# Out:
#   File "C:\Users\GEBRUI~1\AppData\Local\Temp/ipykernel_6656/3580027668.py", line 1
#     def calc_score
#                   ^
# SyntaxError: invalid syntax

# %%
def calc_p(test, full):
    neighbors = [w.neighbors[x] for x in test.index]
    
    p = [full.loc[x].sum() for x in neighbors]
    return pd.DataFrame(test.values + p)

# %%
p = calc_p(X_pred, X_pred).set_index(X_pred.index)

# %%
bag_forest = RandomForestClassifier(max_depth = 4, random_state = 0)
bag_forest.fit(p, Y)
# Out:
# RandomForestClassifier(max_depth=4, random_state=0)

# %%
p.loc[p.nlargest(1254, 0).index] = 1
p[(p != 1).values] = 0

# %%
recall_score(p, y_test)
# Out:
# 0.24401913875598086

# %%
precision_score(p, y_test)
# Out:
# 0.24401913875598086

# %%
import xgboost
from sklearn.model_selection import GridSearchCV,StratifiedKFold

# %%
model = xgboost.XGBClassifier()
kfold = StratifiedKFold(n_splits=10)
params = {
    'n_estimators': [25,50,75,100],
    'max_depth': [1,3,5,7,9,10],
    'learning_rate':[0.001,0.01,0.1,0.25]
}
grid_search = GridSearchCV(model,param_grid=params,cv=kfold,n_jobs=-1)
grid_search.fit(X,Y)
# Out:
# C:\Users\Gebruiker\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:42:32] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, subsample=None,
#                                      tree_method=None, validate_parameters=None,
#                                      verbosity=None),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1, 0.25],
#                          'max_depth': [1, 3, 5, 7, 9, 10],
#                          'n_estimators': [25, 50, 75, 100]})

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.001, max_delta_step=0, max_depth=1,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=25, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 25}

# %%
model = xgboost.XGBClassifier(learning_rate = 0.001, max_depth = 1, n_estimators = 25)

# %%
model.fit(X_train, y_train)
# Out:
# [10:51:47] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.001, max_delta_step=0, max_depth=1,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=25, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
X_pred = model.predict_proba(X)

# %%
a = model.predict(X_test)

# %%
accuracy_score(a, y_test)
# Out:
# 0.904891304347826

# %%
precision_score(a, y_test)
# Out:
# 0.05223880597014925

# %%
recall_score(a, y_test)
# Out:
# 0.12727272727272726

# %%
df.columns
# Out:
# Index(['bijeenkomstfunctie', 'gezondheidszorgfunctie', 'industriefunctie',
#        'kantoorfunctie', 'logiesfunctie', 'onderwijsfunctie', 'sportfunctie',
#        'winkelfunctie', 'woonfunctie', 'oppervlakteVerblijfsobject',
#        'inwoner_g', 'geboorte_g', 'inw_014_g', 'inw_1524_g', 'inw_2544_g',
#        'inw_4564_g', 'inw_65_g', 'p_western_g', 'p_nonWestern_g',
#        'p_buyhouses_g', 'p_rentals_g', 'p_socialHousing_g', 'medianIncome_g',
#        'avg_electricity_g', 'avg_gas_g', 'p_benefits_g', 'afs_haprak_g',
#        'afs_ziek_g', 'afs_superm_g', 'afs_vo_g', 'afs_oprit_g', 'afs_train_g',
#        'afs_transit_g', 'p_buildBefore2000_g', 'p_buildAfter2000_g',
#        'mean_WOZ', 'PLaagste40Inkomen', 'PHoogste20Inkomen', 'C28992R100',
#        'geometry', 'y', 'BU_CODE'],
#       dtype='object')

# %%
corr = df.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_332f8_row0_col0, #T_332f8_row1_col1, #T_332f8_row2_col2, #T_332f8_row3_col3, #T_332f8_row4_col4, #T_332f8_row5_col5, #T_332f8_row6_col6, #T_332f8_row7_col7, #T_332f8_row8_col8, #T_332f8_row9_col9, #T_332f8_row10_col10, #T_332f8_row11_col11, #T_332f8_row12_col12, #T_332f8_row13_col13, #T_332f8_row14_col14, #T_332f8_row15_col15, #T_332f8_row16_col16, #T_332f8_row17_col17, #T_332f8_row18_col18, #T_332f8_row19_col19, #T_332f8_row20_col20, #T_332f8_row21_col21, #T_332f8_row22_col22, #T_332f8_row23_col23, #T_332f8_row24_col24, #T_332f8_row25_col25, #T_332f8_row26_col26, #T_332f8_row27_col27, #T_332f8_row28_col28, #T_332f8_row29_col29, #T_332f8_row30_col30, #T_332f8_row31_col31, #T_332f8_row32_col32, #T_332f8_row33_col33, #T_332f8_row34_col34, #T_332f8_row35_col35, #T_332f8_row36_col36, #T_332f8_row37_col37, #T_332f8_row38_col38 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_332f8_row0_col1, #T_332f8_row9_col6, #T_332f8_row10_col1, #T_332f8_row16_col4, #T_332f8_row22_col6, #T_332f8_row22_col25, #T_332f8_row24_col3, #T_332f8_row27_col2, #T_332f8_row28_col7, #T_332f8_row29_col3, #T_332f8_row30_col6, #T_332f8_row31_col2, #T_332f8_row33_col4, #T_332f8_row34_col6, #T_332f8_row37_col6, #T_332f8_row38_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_332f8_row0_col2, #T_332f8_row5_col7, #T_332f8_row8_col35, #T_332f8_row13_col5, #T_332f8_row18_col7, #T_332f8_row28_col18, #T_332f8_row31_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_332f8_row0_col3, #T_332f8_row2_col16, #T_332f8_row5_col32, #T_332f8_row8_col22, #T_332f8_row9_col10, #T_332f8_row10_col22, #T_332f8_row14_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_332f8_row0_col4, #T_332f8_row2_col30, #T_332f8_row7_col30, #T_332f8_row11_col28, #T_332f8_row16_col30, #T_332f8_row17_col26, #T_332f8_row21_col6, #T_332f8_row24_col0, #T_332f8_row24_col4, #T_332f8_row26_col4, #T_332f8_row26_col7, #T_332f8_row28_col3, #T_332f8_row28_col4, #T_332f8_row29_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_332f8_row0_col5, #T_332f8_row1_col38, #T_332f8_row2_col5, #T_332f8_row14_col27, #T_332f8_row14_col28, #T_332f8_row17_col38, #T_332f8_row21_col5, #T_332f8_row25_col31, #T_332f8_row27_col8, #T_332f8_row37_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_332f8_row0_col6, #T_332f8_row10_col31, #T_332f8_row10_col35, #T_332f8_row13_col27, #T_332f8_row14_col5, #T_332f8_row15_col17, #T_332f8_row16_col11, #T_332f8_row22_col18, #T_332f8_row25_col28, #T_332f8_row33_col3, #T_332f8_row36_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_332f8_row0_col7, #T_332f8_row4_col23, #T_332f8_row4_col37, #T_332f8_row6_col37, #T_332f8_row9_col23, #T_332f8_row13_col14, #T_332f8_row17_col34, #T_332f8_row18_col33, #T_332f8_row31_col12, #T_332f8_row34_col20, #T_332f8_row35_col27 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_332f8_row0_col8, #T_332f8_row4_col36, #T_332f8_row6_col36, #T_332f8_row13_col18, #T_332f8_row20_col34, #T_332f8_row25_col11, #T_332f8_row26_col33, #T_332f8_row33_col19, #T_332f8_row34_col35, #T_332f8_row35_col33, #T_332f8_row38_col36 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_332f8_row0_col9, #T_332f8_row1_col9, #T_332f8_row2_col9, #T_332f8_row3_col9, #T_332f8_row4_col9, #T_332f8_row5_col9, #T_332f8_row6_col9, #T_332f8_row20_col9, #T_332f8_row21_col28, #T_332f8_row23_col0, #T_332f8_row23_col38, #T_332f8_row27_col5, #T_332f8_row27_col6, #T_332f8_row32_col5, #T_332f8_row34_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_332f8_row0_col10, #T_332f8_row2_col11, #T_332f8_row4_col26, #T_332f8_row5_col24, #T_332f8_row11_col22, #T_332f8_row16_col28, #T_332f8_row16_col34, #T_332f8_row22_col31, #T_332f8_row33_col8, #T_332f8_row34_col10, #T_332f8_row38_col12, #T_332f8_row38_col17 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_332f8_row0_col11, #T_332f8_row2_col17, #T_332f8_row6_col8, #T_332f8_row9_col32, #T_332f8_row30_col28 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_332f8_row0_col12, #T_332f8_row3_col12, #T_332f8_row7_col27, #T_332f8_row7_col28, #T_332f8_row7_col32, #T_332f8_row15_col20, #T_332f8_row17_col3, #T_332f8_row24_col13, #T_332f8_row32_col10 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_332f8_row0_col13, #T_332f8_row11_col36, #T_332f8_row16_col21, #T_332f8_row22_col16, #T_332f8_row29_col12, #T_332f8_row36_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_332f8_row0_col14, #T_332f8_row10_col17, #T_332f8_row38_col14 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_332f8_row0_col15, #T_332f8_row6_col32, #T_332f8_row12_col24, #T_332f8_row14_col22, #T_332f8_row30_col12, #T_332f8_row32_col36 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_332f8_row0_col16, #T_332f8_row1_col8, #T_332f8_row3_col11, #T_332f8_row4_col17, #T_332f8_row5_col8, #T_332f8_row6_col13, #T_332f8_row9_col13, #T_332f8_row15_col36, #T_332f8_row16_col17 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_332f8_row0_col17, #T_332f8_row5_col25, #T_332f8_row7_col25, #T_332f8_row13_col25, #T_332f8_row18_col12, #T_332f8_row22_col26, #T_332f8_row27_col16 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_332f8_row0_col18, #T_332f8_row3_col8, #T_332f8_row3_col17, #T_332f8_row5_col13, #T_332f8_row17_col11, #T_332f8_row28_col12, #T_332f8_row30_col15, #T_332f8_row33_col23, #T_332f8_row34_col28, #T_332f8_row34_col32, #T_332f8_row38_col23 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_332f8_row0_col19, #T_332f8_row0_col37, #T_332f8_row3_col22, #T_332f8_row4_col22, #T_332f8_row12_col35, #T_332f8_row32_col16, #T_332f8_row37_col28 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_332f8_row0_col20, #T_332f8_row8_col18, #T_332f8_row26_col27 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_332f8_row0_col21, #T_332f8_row8_col17, #T_332f8_row16_col20, #T_332f8_row17_col14, #T_332f8_row21_col34, #T_332f8_row22_col12, #T_332f8_row31_col22, #T_332f8_row35_col16 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_332f8_row0_col22, #T_332f8_row3_col25, #T_332f8_row4_col15, #T_332f8_row6_col18, #T_332f8_row9_col25, #T_332f8_row14_col13, #T_332f8_row31_col36, #T_332f8_row37_col26 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_332f8_row0_col23, #T_332f8_row3_col23, #T_332f8_row4_col16, #T_332f8_row9_col14, #T_332f8_row11_col17, #T_332f8_row11_col33, #T_332f8_row22_col29, #T_332f8_row26_col16, #T_332f8_row30_col11, #T_332f8_row34_col26, #T_332f8_row37_col29 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_332f8_row0_col24, #T_332f8_row2_col3, #T_332f8_row4_col28, #T_332f8_row6_col17, #T_332f8_row21_col16, #T_332f8_row30_col31, #T_332f8_row37_col16 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_332f8_row0_col25, #T_332f8_row1_col22, #T_332f8_row4_col35, #T_332f8_row6_col14, #T_332f8_row7_col19, #T_332f8_row11_col37, #T_332f8_row12_col27, #T_332f8_row26_col36, #T_332f8_row30_col17, #T_332f8_row30_col37 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_332f8_row0_col26, #T_332f8_row0_col28, #T_332f8_row2_col12, #T_332f8_row2_col27, #T_332f8_row5_col27, #T_332f8_row12_col8, #T_332f8_row12_col33, #T_332f8_row13_col26, #T_332f8_row29_col21, #T_332f8_row30_col29, #T_332f8_row34_col17 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_332f8_row0_col27, #T_332f8_row3_col26, #T_332f8_row3_col28, #T_332f8_row22_col14, #T_332f8_row26_col25, #T_332f8_row33_col26, #T_332f8_row36_col15, #T_332f8_row38_col7, #T_332f8_row38_col28 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_332f8_row0_col29, #T_332f8_row8_col3, #T_332f8_row13_col28, #T_332f8_row15_col21, #T_332f8_row17_col0, #T_332f8_row20_col0, #T_332f8_row20_col3, #T_332f8_row22_col17, #T_332f8_row24_col12, #T_332f8_row25_col12, #T_332f8_row28_col13, #T_332f8_row29_col25, #T_332f8_row32_col20, #T_332f8_row38_col26, #T_332f8_row38_col27 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_332f8_row0_col30, #T_332f8_row6_col30, #T_332f8_row11_col6, #T_332f8_row11_col26, #T_332f8_row20_col22, #T_332f8_row23_col2, #T_332f8_row26_col3, #T_332f8

# %%
corr["woonfunctie"]
# Out:
# bijeenkomstfunctie            0.210158
# gezondheidszorgfunctie        0.040262
# industriefunctie              0.074298
# kantoorfunctie                0.116521
# logiesfunctie                -0.006489
# onderwijsfunctie              0.039107
# sportfunctie                  0.043644
# winkelfunctie                 0.193093
# woonfunctie                   1.000000
# oppervlakteVerblijfsobject   -0.019634
# inwoner_g                     0.275953
# geboorte_g                    0.279053
# inw_014_g                    -0.085333
# inw_1524_g                    0.185879
# inw_2544_g                    0.296900
# inw_4564_g                   -0.305936
# inw_65_g                     -0.136751
# p_western_g                   0.225324
# p_nonWestern_g                0.294212
# p_buyhouses_g                -0.388616
# p_rentals_g                   0.386322
# p_socialHousing_g             0.331561
# medianIncome_g               -0.222997
# avg_electricity_g            -0.449416
# avg_gas_g                    -0.386306
# p_benefits_g                  0.224880
# afs_haprak_g                 -0.327168
# afs_ziek_g                   -0.278945
# afs_superm_g                 -0.338438
# afs_vo_g                     -0.299444
# afs_oprit_g                   0.063157
# afs_train_g                  -0.259977
# afs_transit_g                -0.311996
# p_buildBefore2000_g           0.031484
# p_buildAfter2000_g           -0.030883
# mean_WOZ                     -0.365382
# PLaagste40Inkomen             0.170490
# PHoogste20Inkomen            -0.194561
# y                             0.123996
# Name: woonfunctie, dtype: float64

# %%
df15.shape
# Out:
# (39148, 42)
